# %% [markdown]
# * 해당 노트북은 YouTube [todaycode오늘코드](https://www.youtube.com/channel/UCLR3sD0KB_dWpvcsrLP0aUg) 강의를 기반으로 작성했습니다.
# * 참고한 .ipynb는 다음과 같습니다.[seoul-covid-19-02-eda-output.ipynb](https://colab.research.google.com/github/corazzon/cracking-the-pandas-cheat-sheet/blob/master/seoul-covid-19-02-eda-output.ipynb#scrollTo=IGUx3sdwKXCE)

# %% [markdown]
# # 서울시에서 공개한 코로나19 발생동향 분석
# 이 노트북은 서울시에서 제공하는 코로나 발생 동향 데이터의 여러개의 칼럼 데이터를 중심으로 다양한 관점에서 EDA를 수행한 파일입니다. 코로나 발생 동향 데이터는 [이곳](https://www.seoul.go.kr/coronaV/coronaStatus.do) 웹사이트를 통해 크롤링 할 수 있습니다. 또한, 해당 웹사이트의 테이블 구조가 바뀔 수 있기 때문에 이에 맞춰서 데이터 크롤링을 수행해야 합니다. 이 노트북은 2021년 2월 2일 기준으로 크롤링 한 데이터를 기준으로 분석을 수행했습니다.

# %%
# 필요한 모듈 
import pandas as pd
import numpy as np

# %%
# 2021년 2월 2일 기준 제공된 데이터
file_name = f'data/seoul-covid19-2021_02_01.csv'
file_name
# Out:
# 'data/seoul-covid19-2021_02_01.csv'

# %%
df = pd.read_csv(file_name)
df.shape
# Out:
# (24395, 7)

# %%
df.head()
# Out:
#       연번     환자         확진일  거주지 여행력         접촉력 퇴원현황
# 0  24395  78560  2021-02-01  마포구   -    감염경로 조사중  NaN
# 1  24394  78588  2021-02-01  타시도   -    감염경로 조사중  NaN
# 2  24393  78822  2021-02-01  강남구   -   기타 확진자 접촉  NaN
# 3  24392  78826  2021-02-01  관악구   -  광진구 음식점 관련  NaN
# 4  24391  78825  2021-02-01  관악구   -    감염경로 조사중  NaN

# %%
# 연번 기준으로 역순으로 정렬
df = df.sort_values(by="연번", ascending=False)
df
# Out:
#           연번     환자         확진일  거주지 여행력         접촉력 퇴원현황
# 0      24395  78560  2021-02-01  마포구   -    감염경로 조사중  NaN
# 1      24394  78588  2021-02-01  타시도   -    감염경로 조사중  NaN
# 2      24393  78822  2021-02-01  강남구   -   기타 확진자 접촉  NaN
# 3      24392  78826  2021-02-01  관악구   -  광진구 음식점 관련  NaN
# 4      24391  78825  2021-02-01  관악구   -    감염경로 조사중  NaN
# ...      ...    ...         ...  ...  ..         ...  ...
# 24390      5      9  2020-01-31  성북구   -   기타 확진자 접촉   퇴원
# 24391      4      7  2020-01-30  마포구  중국        해외유입   퇴원
# 24392      3      6  2020-01-30  종로구   -    종로구 집단발병   퇴원
# 24393      2      5  2020-01-30  중랑구  중국        해외유입   퇴원
# 24394      1      2  2020-01-24  강서구  중국        해외유입   퇴원
#
# [24395 rows x 7 columns]

# %% [markdown]
# * 최초 서울시에서 발생한 코로나 확진자는 2020년 1월 24일 중국에 여행력을 가진 강서구 거주자입니다.
# * 데이터 수집 시점(2021년 2월 2일)을 기준으로 가장 최근에 발생한 확진자는 마포구에 거주하는 환자입니다.

# %% [markdown]
# # 시각화 도구 불러오기

# %%
# 한글폰트 설정
import matplotlib.pyplot as plt
# 한글 설정 -> plt.rc 사용
plt.rc("font", family="Malgun Gothic") # Windows
#plt.rc("font", family="AppleGothic") # Mac

# 마이너스(-) 기호 표시를 위한 설정
plt.rc("axes", unicode_minus=False) 

pd.Series([1,3,5,-7,9]).plot.bar(title="한글 제목")

# %% [markdown]
# ## 시각화 선명하게 설정하기

# %%
# retina를 지원한다면, 시각화 폰트를 좀 더 선명하게 볼 수 있습니다.
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

# %% [markdown]
# # 확진일

# %% [markdown]
# 확진일 칼럼의 빈도수를 확인하면, 대부분 2020년 12월에 확진자수가 많은 것을 알 수 있습니다.

# %%
df["확진일"].value_counts()
# Out:
# 2020-12-17    588
# 2020-12-24    566
# 2020-12-28    525
# 2020-12-25    431
# 2020-12-16    427
#              ...
# 2020-01-24      1
# 2020-04-18      1
# 2020-04-30      1
# 2020-04-24      1
# 2020-02-02      1
# Name: 확진일, Length: 343, dtype: int64

# %% [markdown]
# 확진일 칼럼 데이터 타입을 datetime으로 변경합니다.

# %%
df["확진일"] = pd.to_datetime(df["확진일"])

# %% [markdown]
# 확진일 데이터에서 '년도'만 추출하여 새로운 칼럼에 저장합니다. **(데이터를 전처리 할 때는 새로운 칼럼을 생성해서 전처리한 결과를 저장하는 것이 좋습니다.)**

# %%
df["년"] = df["확진일"].dt.year
df[["확진일", "년"]]
# Out:
#              확진일     년
# 0     2021-02-01  2021
# 1     2021-02-01  2021
# 2     2021-02-01  2021
# 3     2021-02-01  2021
# 4     2021-02-01  2021
# ...          ...   ...
# 24390 2020-01-31  2020
# 24391 2020-01-30  2020
# 24392 2020-01-30  2020
# 24393 2020-01-30  2020
# 24394 2020-01-24  2020
#
# [24395 rows x 2 columns]

# %% [markdown]
# 확진일 데이터에서 '월'만 추출하여 새로운 칼럼에 저장합니다.**(데이터를 전처리 할 때는 새로운 칼럼을 생성해서 전처리한 결과를 저장하는 것이 좋습니다.)**

# %%
df["월"] = df["확진일"].dt.month
df[["확진일", "년", "월"]]
# Out:
#              확진일     년  월
# 0     2021-02-01  2021  2
# 1     2021-02-01  2021  2
# 2     2021-02-01  2021  2
# 3     2021-02-01  2021  2
# 4     2021-02-01  2021  2
# ...          ...   ... ..
# 24390 2020-01-31  2020  1
# 24391 2020-01-30  2020  1
# 24392 2020-01-30  2020  1
# 24393 2020-01-30  2020  1
# 24394 2020-01-24  2020  1
#
# [24395 rows x 3 columns]

# %% [markdown]
# 확진일 데이터에서 '주'를 계산하여 새로운 칼럼에 저장합니다. 그 결과, 2020-01-24(4주차)를 기준으로 2021-01-03(53주차)까지 계산하고, 2021-01-04(1주차)를 기준으로 데이터 수집 시점까지 '주'를 계산합니다.

# %%
df["주"] = df["확진일"].dt.week
df[["확진일", "년", "월", "주"]]
# Out:
# <ipython-input-12-9296de6e7598>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df["주"] = df["확진일"].dt.week
#              확진일     년  월  주
# 0     2021-02-01  2021  2  5
# 1     2021-02-01  2021  2  5
# 2     2021-02-01  2021  2  5
# 3     2021-02-01  2021  2  5
# 4     2021-02-01  2021  2  5
# ...          ...   ... .. ..
# 24390 2020-01-31  2020  1  5
# 24391 2020-01-30  2020  1  5
# 24392 2020-01-30  2020  1  5
# 24393 2020-01-30  2020  1  5
# 24394 2020-01-24  2020  1  4
#
# [24395 rows x 4 columns]

# %% [markdown]
# ## 선그래프 그리기
# 전체 날짜를 기준으로 확진자 발생 분포를 선그래프로 확인합니다.

# %% [markdown]
# 날짜 순서대로 시각화하기 위해 sort_index()를 수행합니다.

# %%
df["확진일"].value_counts().sort_index()
# Out:
# 2020-01-24      1
# 2020-01-30      3
# 2020-01-31      3
# 2020-02-02      1
# 2020-02-05      2
#              ...
# 2021-01-28    113
# 2021-01-29    151
# 2021-01-30    101
# 2021-01-31    107
# 2021-02-01    128
# Name: 확진일, Length: 343, dtype: int64

# %% [markdown]
# df.plot()은 기본적으로 '선그래프'를 그리며, 확진자 분포 특징을 알아보기 쉽도록 plt.axhline()을 수행하여 x축과 평행한 라인을 출력합니다.

# %%
df["확진일"].value_counts().sort_index().plot(figsize=(15,4))
plt.axhline(200, color='red', linestyle=":")

# %% [markdown]
# 서울시에서는 2020년 8월 전까지도 꾸준히 확진자가 발생했지만, 해당 시점 이후로 폭발적으로 증가한 것을 알 수 있습니다. 또한, 2020년 11월 이후로 2021년 1월에 이르기까지 확진자수는 이전보다 훨씬 급증하여 하루 600명에 이르는 확진자가 발생하기도 했습니다.

# %% [markdown]
# ## 확진자가 가장 많이 나온날
# 데이터 수집 시점(2021년2월2일)을 기준으로 확진자가 가장 많이 나온날을 좀 더 자세히 살펴보겠습니다.

# %%
day_count = df["확진일"].value_counts().sort_index()
day_count
# Out:
# 2020-01-24      1
# 2020-01-30      3
# 2020-01-31      3
# 2020-02-02      1
# 2020-02-05      2
#              ...
# 2021-01-28    113
# 2021-01-29    151
# 2021-01-30    101
# 2021-01-31    107
# 2021-02-01    128
# Name: 확진일, Length: 343, dtype: int64

# %%
day_count.describe()
# Out:
# count    343.000000
# mean      71.122449
# std      104.464534
# min        1.000000
# 25%        8.000000
# 50%       20.000000
# 75%      102.500000
# max      588.000000
# Name: 확진일, dtype: float64

# %% [markdown]
# 데이터 수집 시점(2021년2월2일)을 기준으로 2020년12월17일에 서울시에 가장 많은 588명 확진자가 발생했습니다.

# %%
day_count[day_count == day_count.max()]
# Out:
# 2020-12-17    588
# Name: 확진일, dtype: int64

# %% [markdown]
# 확진자가 가장 많은 2020년12월17일에 데이터를 살펴봤습니다.

# %%
df[df["확진일"]=='2020-12-17'].head()
# Out:
#          연번     환자        확진일  거주지 여행력       접촉력 퇴원현황     년   월   주
# 7297  17098  48368 2020-12-17  타시도   -  감염경로 조사중   퇴원  2020  12  51
# 7376  17019  54793 2020-12-17  종로구   -  감염경로 조사중   퇴원  2020  12  51
# 9688  14707  49665 2020-12-17   기타   -  동부구치소 관련  NaN  2020  12  51
# 9689  14706  49664 2020-12-17   기타   -  동부구치소 관련   퇴원  2020  12  51
# 9690  14705  49663 2020-12-17   기타   -  동부구치소 관련   퇴원  2020  12  51

# %%
df[df["확진일"]=='2020-12-17']["접촉력"].value_counts().sort_values().plot.barh()

# %% [markdown]
# 2020년12월17일에 발생한 대다수 확진자는 동부구치소 관련된 경우와 다른 확진자 접촉으로 인한 n차 감염이 가장 많았고, 아직 감염 경로를 조사중인 확진자가 뒤를 따르고 있습니다.

# %% [markdown]
# ## 최근 데이터만 슬라이싱으로 나눠 그리기
# 데이터 수집 시점(2021년2월2일)을 기준으로 최근 50일 간의 서울시 확진자 발생 추이를 시각화하여 2020년 12월에 가장 많이 발생한 것을 알 수 있었습니다.

# %%
# 최근 50일 간의 추이만 시각화
g = day_count[-50:].plot.bar(figsize=(15,4))

for i in range(50):
    case_count = day_count[-50:].iloc[i]
    if case_count > 10:
        g.text(x=i-0.5, y=case_count, s=case_count)

# %% [markdown]
# ## 월별 확진자 수 그리기
# 확진자수를 월별로 좀 더 세밀하게 분석하여 12월, 1월 순으로 확진자가 많았음을 알 수 있었습니다.

# %%
df["월"].value_counts()
# Out:
# 12    10428
# 1      4885
# 11     2904
# 8      2415
# 9      1306
# 10      733
# 6       459
# 3       391
# 7       281
# 5       229
# 2       208
# 4       156
# Name: 월, dtype: int64

# %%
month_case = df["월"].value_counts().sort_index()
g = month_case.plot.bar(rot=0)

for i in range(len(month_case)):
    g.text(x=i-0.2, y=month_case.iloc[i]+10, s=month_case.iloc[i])

# %% [markdown]
# 또한, 2020년과 2021년을 분리해서 동일한 절차를 수행한 결과, 1월에 발생한 확진자는 대다수 2021년 1월에 발생했음을 알 수 있었습니다. 2020년12월에 이어 확진자가 지속 발생했음을 알 수 있습니다.

# %%
df.groupby(["월", "년"])["연번"].count().unstack().plot.bar(figsize=(10,4))

# %% [markdown]
# ## 주단위 확진자 수 그리기
# '주' 단위로 확진자수 추이를 분석한 결과, 1주차에서 약 5주차까지는 2021년에 발생한 코로나 확진자의 영향이 있음을 알 수 있습니다.

# %%
weekly_case = df["주"].value_counts().sort_index()
weekly_case.plot(figsize=(15, 4))
plt.grid(True)

# %%
df.groupby(["주", "년"])["연번"].count().unstack().plot(figsize=(15,4))

# %% [markdown]
# # 모든 날짜를 행에 만들어 주기
# 이번에는 수집한 데이터 전체 날짜중에 확진자가 발생하지 않은 날에는 Nan을 가지고 있는 데이터프레임을 생성합니다.
# * step 1) 전체 날짜를 저장하고 있는 새로운 데이터프레임 생성합니다.
# * step 2) 기존 df에서 각 확진날짜에 발생한 확진자수 추출합니다.
# * step 3) step 1, 2에서 생성한 데이터프레임을 merge 합니다.

# %% [markdown]
# 먼저, 최초 df에서 확진자가 발생하지 않은 날짜가 비어있음을 확인할 수 있습니다.

# %%
df["확진일"].astype(str).unique()
# Out:
# array(['2021-02-01', '2021-01-31', '2021-01-30', '2021-01-28',
#        '2021-01-29', '2021-01-27', '2021-01-26', '2021-01-25',
#        '2020-12-16', '2021-01-22', '2020-11-23', '2021-01-24',
#        '2021-01-23', '2021-01-21', '2020-12-27', '2020-12-19',
#        '2021-01-20', '2021-01-19', '2021-01-18', '2021-01-17',
#        '2020-07-20', '2020-07-19', '2020-07-18', '2020-07-17',
#        '2020-07-16', '2020-07-15', '2020-07-14', '2020-07-13',
#        '2020-07-12', '2020-07-11', '2020-07-10', '2020-07-09',
#        '2020-07-08', '2020-07-07', '2020-07-06', '2020-07-05',
#        '2020-07-04', '2020-07-03', '2020-07-02', '2020-07-01',
#        '2020-06-30', '2020-06-29', '2020-06-28', '2020-06-27',
#        '2020-06-26', '2020-06-25', '2020-06-24', '2020-06-23',
#        '2020-06-22', '2020-06-21', '2020-06-20', '2020-06-19',
#        '2020-06-18', '2020-06-17', '2020-06-16', '2020-06-15',
#        '2020-06-14', '2020-06-13', '2020-06-12', '2020-06-11',
#        '2020-06-10', '2020-06-09', '2020-06-08', '2020-06-07',
#        '2020-06-06', '2020-06-05', '2020-06-04', '2020-06-03',
#        '2020-06-02', '2020-06-01', '2020-05-31', '2020-05-30',
#        '2020-05-29', '2020-05-27', '2020-05-28', '2020-05-26',
#        '2020-05-25', '2020-05-24', '2020-05-23', '2020-05-22',
#        '2020-05-21', '2020-05-20', '2020-05-19', '2020-05-18',
#        '2020-05-17', '2020-05-16', '2020-05-15', '2020-05-14',
#        '2020-05-13', '2020-05-12', '2020-05-11', '2020-05-10',
#        '2020-05-09', '2020-05-08', '2020-05-02', '2020-05-01',
#        '2020-04-30', '2020-04-27', '2020-04-24', '2020-04-21',
#        '2020-04-02', '2020-04-19', '2020-04-18', '2020-04-17',
#        '2020-04-16', '2020-04-15', '2020-04-14', '2020-04-13',
#        '2020-04-12', '2020-04-11', '2020-04-10', '2020-04-09',
#        '2020-04-08', '2020-04-07', '2020-04-06', '2020-04-05',
#        '2020-04-04', '2020-04-03', '2020-04-01', '2020-03-31',
#        '2020-03-30', '2020-03-29', '2020-03-28', '2020-03-27',
#        '2020-03-25', '2020-03-26', '2020-03-24', '2020-03-23',
#        '2020-03-22', '2020-03-21', '2020-03-20', '2020-03-19',
#        '2020-03-18', '2020-03-17', '2020-03-16', '2020-03-15',
#        '2020-03-14', '2020-03-13', '2020-03-12', '2020-03-11',
#        '2020-03-10', '2020-03-09', '2020-03-08', '2020-03-07',
#        '2020-03-06', '2020-03-05', '2020-03-04', '2020-03-02',
#        '2020-03-01', '2020-02-29', '2020-02-27', '2020-02-28',
#        '2020-02-26', '2020-02-25', '2020-02-24', '2020-02-22',
#        '2020-02-23', '2020-02-21', '2020-02-20', '2020-02-19',
#        '2020-02-16', '2020-02-06', '2020-02-05', '2020-02-02',
#        '2020-01-31', '2020-01-30', '2020-01-24'], dtype=object)

# %% [markdown]
# **step 1) 전체 날짜를 저장하고 있는 새로운 데이터프레임 생성하는 과정입니다.**

# %% [markdown]
# 첫 번째 확진일과 마지막 확진일을 구하는 코드의 실행 시간을 측정하기 위해 %timeit을 사용합니다.
#
# * %timeit: 코드 한 줄을 n번(default: 7번) 실행시킬 때의 평균 소요시간(mean) 및 표준편차(std) 계산

# %%
df.sample()
# Out:
#           연번     환자        확진일  거주지 여행력             접촉력 퇴원현황     년   월   주
# 14395  10000  37131 2020-12-05  금천구   -  구로구 소재 보험회사 관련   퇴원  2020  12  49

# %% [markdown]
# 첫 번째 확진일자는 df의 가장 아래 row에 존재하며, 3번째 칼럼에 있습니다.

# %%
# %timeit first_day = df.iloc[-1, 2] # 첫 번쩨 확진일자
# Out:
# 48.4 µs ± 3.54 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit last_day = df.iloc[0, 2] # 최근 확진일자
# Out:
# 51.9 µs ± 2.68 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# 이 때, first_day나 last_day를 실행하면 정의되어 있지 않은 변수로 판단합니다. 아직 확실하지는 않지만, **위 %timeit은 단순히 코드 실행 시간만 측정하고, 변수를 정의하는 것은 아닌지 확인이 필요할 것 같습니다.** 따라서 아래와 같이 first_day와 last_day 변수를 다시 정의했습니다.

# %%
first_day = df.iloc[-1, 2]
last_day = df.iloc[0, 2]

# %% [markdown]
# 이제 pd.date_range()를 사용하여 first_day(2020-01-24)부터 last_day(2020-06-30) 사이의 모든 날짜를 생성하고, 데이터프레임으로 변환합니다.

# %%
days = pd.date_range(first_day, last_day)
days
# Out:
# DatetimeIndex(['2020-01-24', '2020-01-25', '2020-01-26', '2020-01-27',
#                '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31',
#                '2020-02-01', '2020-02-02',
#                ...
#                '2021-01-23', '2021-01-24', '2021-01-25', '2021-01-26',
#                '2021-01-27', '2021-01-28', '2021-01-29', '2021-01-30',
#                '2021-01-31', '2021-02-01'],
#               dtype='datetime64[ns]', length=375, freq='D')

# %%
df_days = pd.DataFrame({"확진일자": days})
df_days.head()
# Out:
#         확진일자
# 0 2020-01-24
# 1 2020-01-25
# 2 2020-01-26
# 3 2020-01-27
# 4 2020-01-28

# %% [markdown]
# **step 2) 기존 df에서 각 확진날짜에 발생한 확진자수 추출합니다.**

# %%
daily_case = df["확진일"].value_counts()
daily_case
# Out:
# 2020-12-17    588
# 2020-12-24    566
# 2020-12-28    525
# 2020-12-25    431
# 2020-12-16    427
#              ...
# 2020-03-05      1
# 2020-04-15      1
# 2020-01-24      1
# 2020-04-19      1
# 2020-04-24      1
# Name: 확진일, Length: 343, dtype: int64

# %%
# 데이터프레임으로 변환 및 칼럼명 변경
df_daily_case = daily_case.to_frame()
df_daily_case.columns = ["확진수"]
df_daily_case
# Out:
#             확진수
# 2020-12-17  588
# 2020-12-24  566
# 2020-12-28  525
# 2020-12-25  431
# 2020-12-16  427
# ...         ...
# 2020-03-05    1
# 2020-04-15    1
# 2020-01-24    1
# 2020-04-19    1
# 2020-04-24    1
#
# [343 rows x 1 columns]

# %% [markdown]
# ## merge를 통해 전체 확진일자 만들기
# **step 3) step 1, 2에서 생성한 데이터프레임을 merge 합니다.**

# %%
all_days = df_days.merge(df_daily_case, left_on="확진일자", right_index=True, how='left')
all_days
# Out:
#           확진일자    확진수
# 0   2020-01-24    1.0
# 1   2020-01-25    NaN
# 2   2020-01-26    NaN
# 3   2020-01-27    NaN
# 4   2020-01-28    NaN
# ..         ...    ...
# 370 2021-01-28  113.0
# 371 2021-01-29  151.0
# 372 2021-01-30  101.0
# 373 2021-01-31  107.0
# 374 2021-02-01  128.0
#
# [375 rows x 2 columns]

# %% [markdown]
# 우리가 원하는대로 확진자가 발생하지 않은 날짜의 확진수에는 Nan으로 채워 넣은 데이터프레임을 생성할 수 있었습니다.

# %% [markdown]
# # 누적 확진자 수 구하기
# 위에서 생성한 all_days(전체 날짜에 대한 확진자수를 저장) 데이터프레임을 사용하여 누적 확진자수를 계산합니다. <font color='red'>'누적수'는 시간에 따른 변화 또는 추이를 쉽게 확인할 수 있는 지표로 활용할 수 있습니다.</font>

# %% [markdown]
# all_days 데이터프레임의 Nan을 '0'으로 채우고, 누적합(cumsum)을 계산한 값을 새로운 칼럼으로 저장합니다. **(데이터를 전처리 할 때는 새로운 칼럼을 생성해서 전처리한 결과를 저장하는 것이 좋습니다.)**

# %%
all_days["확진수"] = all_days["확진수"].fillna(0)
all_days["누적확진"] = all_days["확진수"].cumsum()
all_days
# Out:
#           확진일자    확진수     누적확진
# 0   2020-01-24    1.0      1.0
# 1   2020-01-25    0.0      1.0
# 2   2020-01-26    0.0      1.0
# 3   2020-01-27    0.0      1.0
# 4   2020-01-28    0.0      1.0
# ..         ...    ...      ...
# 370 2021-01-28  113.0  23908.0
# 371 2021-01-29  151.0  24059.0
# 372 2021-01-30  101.0  24160.0
# 373 2021-01-31  107.0  24267.0
# 374 2021-02-01  128.0  24395.0
#
# [375 rows x 3 columns]

# %% [markdown]
# 위 결과를 선 그래프로 시각화하기 위해 확진일자 칼럼을 데이터프레임 index로 설정합니다.

# %%
cum_day = all_days.set_index("확진일자")
cum_day.head()
# Out:
#             확진수  누적확진
# 확진일자
# 2020-01-24  1.0   1.0
# 2020-01-25  0.0   1.0
# 2020-01-26  0.0   1.0
# 2020-01-27  0.0   1.0
# 2020-01-28  0.0   1.0

# %% [markdown]
# ## 데이터프레임으로 그리기
# df.plot()을 사용하여 선 그래프로 시각화한 결과입니다. 2020년8월 이전까지는 누적 확진수가 꾸준히 증가하다가 이후로 증가폭이 커짐을 알 수 있습니다. 또한, 2020년11월부터는 누적 확진자수가 매우 가파르게 증가함을 알 수 있습니다.

# %%
cum_day.plot(figsize=(15,4))
plt.grid(True)

# %% [markdown]
# ## 시리즈로 그리기
# 위와 동일한 시각화 결과를 확진수 칼럼 Series와 누적확진 칼럼 Series를 각각 plot()을 수행하여 나타낼 수 있습니다.

# %%
cum_day["확진수"].plot()
cum_day["누적확진"].plot(figsize=(15,4))
plt.grid(True)

# %% [markdown]
# ## 확진수만 따로 그리기
# 누적확진수와 확진수 간의 차이가 크기 때문에 확진수만 따로 시각화를 수행했습니다. 그 결과 처음에 **3.1  선그래프 그리기**에서 도출한 확진자수를 분포를 확인할 수 있었습니다.

# %%
cum_day["확진수"].plot(figsize=(15,4))
plt.grid(True)

# %% [markdown]
# ## 누적확진만 따로 그리기
# 마찬가지로, 누적확진만 따로 시각화를 수행했습니다.

# %%
cum_day["누적확진"].plot(figsize=(15,4))
plt.grid(True)

# %% [markdown]
# ## 로그 스케일
# 시각화 한 데이터 간의 차이가 너무 큰 경우에는 '로그 스케일'로 변환하면, 더 쉽게 알아볼 수 있습니다.
# * '로그 스케일'은 상대적으로 작은값은 큰 값으로 스케일링하고, 큰 값은 작은값으로 스케일링하는 특성이 있기 때문에 **작은값의 분포를 좀 더 자세히 확인할 수 있습니다.**
# * 확진자가 없는 날의 '0'은 로그 스케일로 변환 시, (-) 무한대로 발산하므로, 아래와 같이 라인이 중간에 짤려 있습니다. 하지만, 대다수 날짜에 확진자가 발생했음을 알 수 있습니다.

# %%
np.log(cum_day["확진수"]).plot(figsize=(15,4))
np.log(cum_day["누적확진"]).plot()
plt.grid(True)
# Out:
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# ## 확진월과 요일 구하기
# 확진수와 누적확진을 '년도', '월'과 '요일' 단위로 확인하기 위해 새로운 칼럼을 생성합니다. **(데이터를 전처리 할 때는 새로운 칼럼을 생성해서 전처리한 결과를 저장하는 것이 좋습니다.)**

# %%
all_days.sample()
# Out:
#           확진일자    확진수    누적확진
# 305 2020-11-24  142.0  7901.0

# %%
all_days["확진년도"] = all_days["확진일자"].dt.year
all_days["확진월"] = all_days["확진일자"].dt.month
all_days["확진요일"] = all_days["확진일자"].dt.dayofweek
all_days.head()
# Out:
#         확진일자  확진수  누적확진  확진년도  확진월  확진요일
# 0 2020-01-24  1.0   1.0  2020    1     4
# 1 2020-01-25  0.0   1.0  2020    1     5
# 2 2020-01-26  0.0   1.0  2020    1     6
# 3 2020-01-27  0.0   1.0  2020    1     0
# 4 2020-01-28  0.0   1.0  2020    1     1

# %% [markdown]
# # 요일별 확진 수
# 2020년도와 2021년의 요일별 확진자 수를 시각화합니다. 먼저, 2020년 데이터와 2021년 데이터를 분리합니다.

# %%
all_days_2020 = all_days[all_days["확진년도"]==2020]
all_days_2020.head()
# Out:
#         확진일자  확진수  누적확진  확진년도  확진월  확진요일
# 0 2020-01-24  1.0   1.0  2020    1     4
# 1 2020-01-25  0.0   1.0  2020    1     5
# 2 2020-01-26  0.0   1.0  2020    1     6
# 3 2020-01-27  0.0   1.0  2020    1     0
# 4 2020-01-28  0.0   1.0  2020    1     1

# %%
all_days_2021 = all_days[all_days["확진년도"]==2021]
all_days_2021.head()
# Out:
#           확진일자    확진수     누적확진  확진년도  확진월  확진요일
# 343 2021-01-01  248.0  19637.0  2021    1     4
# 344 2021-01-02  191.0  19828.0  2021    1     5
# 345 2021-01-03  330.0  20158.0  2021    1     6
# 346 2021-01-04  194.0  20352.0  2021    1     0
# 347 2021-01-05  260.0  20612.0  2021    1     1

# %% [markdown]
# 2020년, 2021년으로 분리한 데이터를 (확진월, 확진요일)별로 그룹핑 이후에, unstack을 수행하여 pivot 형태로 생성합니다.

# %%
# 2020
all_day_2020_week = all_days_2020.groupby(["확진월", "확진요일"])["확진수"].sum()
all_day_2020_week = all_day_2020_week.unstack()
all_day_2020_week.columns = ["월", "화", "수", "목", "금", "토", "일"]

# 2021
all_day_2021_week = all_days_2021.groupby(["확진월", "확진요일"])["확진수"].sum()
all_day_2021_week = all_day_2021_week.unstack(fill_value=0)
all_day_2021_week.columns = ["월", "화", "수", "목", "금", "토", "일"]

# %% [markdown]
# 2020년
# * 앞에서 살펴본 것과 같이 8월에 확진자가 급증하다가 잠잠해졌으며, 11월 이후로 다시 급증하는 것을 확인할 수 있습니다.

# %%
all_day_2020_week.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# #T_1ff16666_65e7_11eb_a658_54e1ade7a93crow0_col0,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow0_col1,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow0_col2,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow0_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow0_col4,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow0_col5,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow0_col6,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow1_col1,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow1_col2,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow1_col5,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow3_col0,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow3_col1{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow1_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow1_col4,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow1_col6{
#             background-color:  #f6faff;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow2_col0,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow5_col5,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow9_col0{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow2_col1{
#             background-color:  #ecf4fb;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow2_col2,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow4_col5,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow4_col6,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow6_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow2_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow4_col1,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow4_col2,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow4_col4,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow6_col4{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow2_col4,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow5_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow5_col6,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow6_col5{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow2_col5{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow2_col6,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow9_col2{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow3_col2,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow3_col4,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow3_col5,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow3_col6,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow4_col0{
#             background-color:  #f4f9fe;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow3_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow4_col3{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow5_col0,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow5_col1,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow5_col2{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow5_col4{
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow6_col1,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow6_col2,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow6_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow6_col6{
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow7_col0{
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow7_col1{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow7_col2{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow7_col3{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow7_col4{
#             background-color:  #caddf0;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow7_col5,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow10_col6{
#             background-color:  #9dcae1;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow7_col6{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow8_col0{
#             background-color:  #dceaf6;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow8_col1{
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow8_col2{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow8_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow8_col6{
#             background-color:  #e3eef8;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow8_col4,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow9_col5{
#             background-color:  #e4eff9;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow8_col5{
#             background-color:  #deebf7;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow9_col1{
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow9_col3{
#             background-color:  #ebf3fb;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow9_col4{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow9_col6{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow10_col0{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow10_col1{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow10_col2{
#             background-color:  #c4daee;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow10_col3{
#             background-color:  #cddff1;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow10_col4{
#             background-color:  #b3d3e8;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow10_col5{
#             background-color:  #aed1e7;
#             color:  #000000;
#         }#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow11_col0,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow11_col1,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow11_col2,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow11_col3,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow11_col4,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow11_col5,#T_1ff16666_65e7_11eb_a658_54e1ade7a93crow11_col6{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }</style><table id="T_1ff16666_65e7_11eb_a658_54e1ade7a93c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >월</th>        <th class="col_heading level0 col1" >화</th>        <th class="col_heading level0 col2" >수</th>        <th class="col_heading level0 col3" >목</th>        <th class="col_heading level0 col4" >금</th>        <th class="col_heading level0 col5" >토</th>        <th class="col_heading level0 col6" >일</th>    </tr>    <tr>        <th class="index_name level0" >확진월</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>

# %% [markdown]
# 2020년
# * 코로나 검사 건수는 주말보다 평일이 많기 때문에 평일 확진자가 많습니다.
# * 평일 중에서는 대체로 월-수 보다는 목-금이 확진자수가 증가합니다. 평일 초반에 일상에서 감염되어 평일 말에 확진 판정을 받지 않을까 유추할 수 있습니다.

# %%
all_day_2020_week.style.highlight_max(axis=1)
# Out:
# <style  type="text/css" >
# #T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col4,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col1,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col3,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col1,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col2,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col3,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col1,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col4,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow6_col3,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow7_col5,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow8_col1,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow9_col4,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow10_col3,#T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow11_col3{
#             background-color:  yellow;
#         }</style><table id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >월</th>        <th class="col_heading level0 col1" >화</th>        <th class="col_heading level0 col2" >수</th>        <th class="col_heading level0 col3" >목</th>        <th class="col_heading level0 col4" >금</th>        <th class="col_heading level0 col5" >토</th>        <th class="col_heading level0 col6" >일</th>    </tr>    <tr>        <th class="index_name level0" >확진월</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93clevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col0" class="data row0 col0" >0.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col3" class="data row0 col3" >3.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col4" class="data row0 col4" >4.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col5" class="data row0 col5" >0.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow0_col6" class="data row0 col6" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93clevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col0" class="data row1 col0" >4.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col1" class="data row1 col1" >16.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col2" class="data row1 col2" >14.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col3" class="data row1 col3" >16.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col4" class="data row1 col4" >14.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col5" class="data row1 col5" >10.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow1_col6" class="data row1 col6" >6.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93clevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col0" class="data row2 col0" >68.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col1" class="data row2 col1" >89.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col2" class="data row2 col2" >48.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col3" class="data row2 col3" >44.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col4" class="data row2 col4" >48.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col5" class="data row2 col5" >45.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow2_col6" class="data row2 col6" >49.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93clevel0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col0" class="data row3 col0" >15.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col1" class="data row3 col1" >17.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col2" class="data row3 col2" >28.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col3" class="data row3 col3" >28.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col4" class="data row3 col4" >26.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col5" class="data row3 col5" >23.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow3_col6" class="data row3 col6" >19.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93clevel0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col0" class="data row4 col0" >26.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col1" class="data row4 col1" >37.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col2" class="data row4 col2" >33.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col3" class="data row4 col3" >34.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col4" class="data row4 col4" >32.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col5" class="data row4 col5" >36.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow4_col6" class="data row4 col6" >31.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93clevel0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col0" class="data row5 col0" >55.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col1" class="data row5 col1" >65.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col2" class="data row5 col2" >66.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col3" class="data row5 col3" >74.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col4" class="data row5 col4" >92.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col5" class="data row5 col5" >69.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow5_col6" class="data row5 col6" >38.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93clevel0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow6_col0" class="data row6 col0" >38.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow6_col1" class="data row6 col1" >42.000000</td>
#                         <td id="T_1ff5f71f_65e7_11eb_8314_54e1ade7a93crow6_col2" class="da

# %% [markdown]
# 2021년
# * 2021년1월은 2020년12월에 이어 확진자가 계속 발생하는 추세입니다. 2021년2월은 2021-02-01 데이터 일부만 수집된 형태이므로, 의미를 부여하기 어렵습니다.

# %%
all_day_2021_week.style.background_gradient(cmap="Greens")
# Out:
# <style  type="text/css" >
# #T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col0,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col1,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col2,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col3,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col4,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col5,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col6{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col0,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col1,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col2,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col3,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col4,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col5,#T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col6{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >월</th>        <th class="col_heading level0 col1" >화</th>        <th class="col_heading level0 col2" >수</th>        <th class="col_heading level0 col3" >목</th>        <th class="col_heading level0 col4" >금</th>        <th class="col_heading level0 col5" >토</th>        <th class="col_heading level0 col6" >일</th>    </tr>    <tr>        <th class="index_name level0" >확진월</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93clevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col0" class="data row0 col0" >564.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col1" class="data row0 col1" >684.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col2" class="data row0 col2" >663.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col3" class="data row0 col3" >536.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col4" class="data row0 col4" >869.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col5" class="data row0 col5" >755.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow0_col6" class="data row0 col6" >807.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93clevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col0" class="data row1 col0" >128.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col4" class="data row1 col4" >0.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col5" class="data row1 col5" >0.000000</td>
#                         <td id="T_1ffbe684_65e7_11eb_9408_54e1ade7a93crow1_col6" class="data row1 col6" >0.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 2021년
# * 2021년1월은 기존과 다르게 주말에 확진자수가 평일보다 대체로 높게 나왔음을 알 수 있습니다.

# %%
all_day_2021_week.style.highlight_max(axis=1)
# Out:
# <style  type="text/css" >
# #T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col4,#T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col0{
#             background-color:  yellow;
#         }</style><table id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >월</th>        <th class="col_heading level0 col1" >화</th>        <th class="col_heading level0 col2" >수</th>        <th class="col_heading level0 col3" >목</th>        <th class="col_heading level0 col4" >금</th>        <th class="col_heading level0 col5" >토</th>        <th class="col_heading level0 col6" >일</th>    </tr>    <tr>        <th class="index_name level0" >확진월</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93clevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col0" class="data row0 col0" >564.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col1" class="data row0 col1" >684.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col2" class="data row0 col2" >663.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col3" class="data row0 col3" >536.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col4" class="data row0 col4" >869.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col5" class="data row0 col5" >755.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow0_col6" class="data row0 col6" >807.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93clevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col0" class="data row1 col0" >128.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col1" class="data row1 col1" >0.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col3" class="data row1 col3" >0.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col4" class="data row1 col4" >0.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col5" class="data row1 col5" >0.000000</td>
#                         <td id="T_1fff3f99_65e7_11eb_8f7a_54e1ade7a93crow1_col6" class="data row1 col6" >0.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # 거주지별 확진자

# %% [markdown]
# 거주지 칼럼의 unique한 데이터를 확인해보면, 이름 앞, 뒤로 공백을 집어넣은 경우가 있습니다. 이 공백들을 모두 제거합니다.

# %%
df["거주지"].unique()
# Out:
# array(['마포구', '타시도', '강남구', '관악구', '영등포구', '노원구', '광진구', '동대문구', '용산구',
#        '도봉구', '서대문구', '성북구', '강동구', '성동구', '기타', '중랑구', '강북구', '중구',
#        '구로구', '종로구', '송파구', '동작구', '금천구', '서초구', '은평구', '강서구', '양천구',
#        '동대문구 ', '노원구 ', '강서구 ', '마포구 ', '성북구 ', '강남구 ', '동작구 ', '강동구 ',
#        '송파구 ', '용산구 ', '관악구 ', '서초구 ', '타시도 ', ' 관악구 ', ' 도봉구 ', '중랑구 ',
#        ' 노원구 ', '은평구 ', '서대문구 ', '금천구 ', '양천구 ', '구로구 ', ' 성동구', '강북구 ',
#        '성동구 ', '영등포구 ', '도봉구 ', '광진구 '], dtype=object)

# %%
df["거주지"] = df["거주지"].str.strip() # .strip(): 문자열 양쪽 공백 제거
df["거주지"].unique()
# Out:
# array(['마포구', '타시도', '강남구', '관악구', '영등포구', '노원구', '광진구', '동대문구', '용산구',
#        '도봉구', '서대문구', '성북구', '강동구', '성동구', '기타', '중랑구', '강북구', '중구',
#        '구로구', '종로구', '송파구', '동작구', '금천구', '서초구', '은평구', '강서구', '양천구'],
#       dtype=object)

# %% [markdown]
# 전처리한 데이터를 가지고 거주지 별 확진자를 확인한 결과, 기타로 분류된 곳에 거주하는 확진자가 가장 많았고, 강서구, 송파구, 관악구, 강남구 순으로 많음을 알 수 있습니다.

# %%
gu_count = df["거주지"].value_counts()
gu_count
# Out:
# 기타      1835
# 강서구     1562
# 송파구     1364
# 관악구     1192
# 강남구     1165
# 타시도     1135
# 노원구     1037
# 성북구     1029
# 동작구     1011
# 중랑구     1008
# 은평구      976
# 서초구      972
# 양천구      900
# 동대문구     893
# 영등포구     887
# 마포구      855
# 구로구      787
# 강동구      750
# 도봉구      745
# 서대문구     664
# 강북구      629
# 성동구      592
# 광진구      590
# 용산구      533
# 종로구      515
# 금천구      396
# 중구       373
# Name: 거주지, dtype: int64

# %%
gu_count.sort_values().plot.barh(figsize=(10, 12))

# %% [markdown]
# 위 결과에서 '기타', '타시도'에 거주하는 확진자(=> 거주지는 '기타' 또는 '타시도', 확진은 '서울'에서 받음)를 제외하고, 서울에만 거주하는 확진자 데이터를 추출합니다.서울에 거주하는 사람은 데이터가 모두 '구'로 끝난다는 점을 사용합니다.

# %%
gu_count = gu_count[gu_count.index.str[-1]=='구']
gu_count
# Out:
# 강서구     1562
# 송파구     1364
# 관악구     1192
# 강남구     1165
# 노원구     1037
# 성북구     1029
# 동작구     1011
# 중랑구     1008
# 은평구      976
# 서초구      972
# 양천구      900
# 동대문구     893
# 영등포구     887
# 마포구      855
# 구로구      787
# 강동구      750
# 도봉구      745
# 서대문구     664
# 강북구      629
# 성동구      592
# 광진구      590
# 용산구      533
# 종로구      515
# 금천구      396
# 중구       373
# Name: 거주지, dtype: int64

# %% [markdown]
# 시각화 결과, 이전에 '기타' 또는 '타시도' 데이터를 제외할 수 있습니다. <font color='red'>추후 결과를 '서울시 지도'에 시각화하면, 확진자 현황을 파악하기에 쉬울 것 같습니다. </font> -> folium 사용?

# %%
gu_count.sort_values().plot.barh(figsize=(10,12))

# %% [markdown]
# 서울 '구' 별 확진자수 데이터프레임을 생성합니다.

# %%
df_gu_count = gu_count.reset_index().rename(columns={"index": '구', "거주지": '확진수'})
df_gu_count.head()
# Out:
#      구   확진수
# 0  강서구  1562
# 1  송파구  1364
# 2  관악구  1192
# 3  강남구  1165
# 4  노원구  1037

# %% [markdown]
# 다시 전체 거주지 별 확진자를 확인합니다. 거주지가 타시도인데, 서울에서 확진을 받은 환자도 상위권입니다. 즉, 이 환자들이 거주지인 타시도로 이동하면, 지역 감염으로 번질 위험이 있습니다.

# %%
gu_etc_count = df["거주지"].value_counts()
gu_etc_count.sort_values().plot.barh(figsize=(10, 12))

# %% [markdown]
# # 접촉력

# %% [markdown]
# 접촉력 데이터를 확인해서 전처리가 필요한 데이터를 선별합니다.
# * 성동구 소재 병원 관련(\\\\\\'21.1월) -> 성동구 소재 병원 관련('21.1월)
# * 성동구 소재 병원 관련(\\\\\\\\\\\\\\'21.1월) -> 성동구 소재 병원 관련('21.1월)
# * 기타확진자 접촉 -> 기타 확진자 접촉

# %%
df["접촉력"].unique()
# Out:
# array(['감염경로 조사중', '기타 확진자 접촉', '광진구 음식점 관련', '해외유입', '중구 소재 복지시설 관련',
#        '중구 소재 콜센터4 관련', '타시도 확진자 접촉', "성동구 소재 병원 관련('21.1월)", '병원 및 요양시설',
#        '동대문구 소재 고시텔 관련', '성북구 소재 사우나 관련', '강동구 소재 한방병원 관련',
#        '성동구 소재 사우나 관련', "성동구 소재 병원 관련(\\'21.1월)", '강남구 소재 직장3 관련',
#        '강남구 소재 선교회 교육시설 관련', "성동구 소재 병원 관련(\\\\\\'21.1월)",
#        '은평구 소재 병원2 관련', '동작구 소재 병원 관련', '도봉구 소재 교회 관련',
#        '서대문구 소재 의료기관/종교시설 관련', '강남구 소재 직장2 관련', '용산구 소재 미군기지 관련',
#        '강남구 소재 직장4 관련', "성동구 소재 병원 관련(\\\\\\\\\\\\\\'21.1월)",
#        '노원구 소재 요양시설 관련', '동대문구 소재 직장 관련', '성동구 소재 거주시설/요양시설 관련',
#        '종로구 소재 직장관련', '종로구 소재 빌딩관련', '영등포구 소재 의료기관2 관련', '송파구 소재 시장 관련',
#        '동대문구 소재 현대대중사우나 관련', '대전 IM선교회 관련', '금천구 소재 직장 관련',
#        '구로구 소재 직장 관련', '강동구 가족관련', '동대문구 지혜병원 관련', '도봉구 소재 직장 관련',
#        '도봉구 소재 어린이집 관련', '종로구 소재 요양시설2 관련', '은평구 소재 병원1 관련',
#        '중구 소재 직장2 관련', '동부구치소 관련', '강남구 소재 사우나 관련', '양천구 소재 직장 관련',
#        '강북구 소재 아동관련 시설', '강남구 소재 직장1 관련', '상주 BTJ 열방센터 관련', '마포구 소재 종교시설',
#        '종로구 소재 콜센터 관련', '송파구 소재 고시텔 관련', '동대문구 소재 대학교 관련',
#        '종로구 소재 사우나 관련', '양천구 소재 요양시설2 관련', '동대문구 소재 역사 관련',
#        '광진구 소재 요양시설 관련', '동작구 소재 직장관련', '서대문구 소재 종교시설 관련',
#        '구로구 소재 요양병원/요양원 관련', '중랑구 소재 종교시설 관련', '강동구 소재 요양병원 관련',
#        '강남역삼동금융회사', '관악구 사무실 관련 ', '타시도 확진자 접촉\r\n(수원 베이비시터 관련)',
#        '강남 이동통신 종사자', '강남구 역삼동 모임 ', '타시도 확진자 접촉\r\n(의정부아파트관련)',
#        '강남구 소재 사무실 ', '관악구 왕성교회', '중랑구 일가족', '관악구 중국동포 일가족', '대전 꿈꾸는 교회',
#        '리치웨이', '현대카드\r\n관악구 왕성교회', '예스병원', '대전 다단계 관련', '리치웨이\r\n[명성하우징]',
#        '도봉구 요양시설 관련', '리치웨이\r\n[SJ투자회사]', '리치웨이\r\n[이민자 쉼터]',
#        '서울시청역 시설개선공사 안전요원관련', '대자연 코리아', '의왕 롯데 물류센터 관련', '금천구 도정기회사 관련',
#        '양천구운동시설', '강남구 오렌지라이프 관련', '수도권 개척교회모임', '국방안보지원사령부 ',
#        '연아나 뉴스클래스', '예수제자교회\r\n한국대학생\r\n선교회(CCC)\r\n관련', '부천 대웅제약',
#        '리치웨이\r\n[예수비젼성결교회]', 'KB생명', 'coupang', '이태원 클럽 관련', '용인형제',
#        '삼성화재', '서초구 가족관련', '안양 목회자\r\n관련', '(인천계양구일가족관련) 연세나로학원',
#        '강남구 동인교회 관련\r\n(구리시 일가족)', '원어성경연구회', '관악구 투석환자 관련', '은평구가족 관련',
#        '영랜브란트미술학원', '삼성서울병원', '위에화엔터테인먼트', '타시도 확진자 접촉\r\n[의정부성모]',
#        '만민중앙교회', '의정부성모', 'Liquid Soul', 'ㅋㅋ트랜드', '이에스에스콤글로벌', '서울아산병원',
#        'Ace 손해보험', '플링크(IT기업)', '성남 은혜의강 교회', '삼성물산', '동대문관련(교회pc방)',
#        'EZHLD', '동대문관련(요양보호사)', '신 천 지', '세브란스', '성동구 아파트 관리사무소',
#        '은평성모병원', '명성교회', '종로구 집단발병'], dtype=object)

# %% [markdown]
# '성동구 소재 병원 관련(\\\\\\'21.1월)' 및 '성동구 소재 병원 관련(\\\\\\\\\\\\\\'21.1월)'를 '성동구 소재 병원 관련('21.1월)'으로 변경합니다.

# %%
df.loc[(df["접촉력"].str.contains("성동구 소재 병원 관련"))&(df["접촉력"].str.contains("21.1월")), "접촉력"] = "성동구 소재 병원 관련('21.1월)"
# Out:
#         연번     환자        확진일   거주지 여행력                   접촉력 퇴원현황     년  월  주
# 35   24360  78841 2021-02-01   타시도   -  성동구 소재 병원 관련('21.1월)  NaN  2021  2  5
# 89   24306  78622 2021-02-01   은평구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  2  5
# 93   24302  78625 2021-02-01   성동구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  2  5
# 94   24301  78726 2021-02-01   관악구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  2  5
# 130  24265  78484 2021-01-31   강남구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 131  24264  78471 2021-01-31   강남구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 140  24255  78429 2021-01-31    기타   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 141  24254  78439 2021-01-31    기타   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 145  24250  78437 2021-01-31    기타   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 146  24249  78430 2021-01-31   성동구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 178  24217  78423 2021-01-31   동작구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 189  24206  78327 2021-01-31  동대문구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 194  24201  78283 2021-01-31   금천구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 220  24175  78334 2021-01-31   중랑구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 226  24169  78281 2021-01-31   관악구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 227  24168  78288 2021-01-31    기타   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
# 232  24163  78282 2021-01-31  동대문구   -  성동구 소재 병원 관련('21.1월)  NaN  2021  1  4
#
#        '강남구 사무실 (K빌딩)', '송파구 지인모임', '관악구 사무실 관련', '강남구 사무실(V빌딩, 한화생명)',
#        '강남역삼동금융회사', '관악구 사무실 관련 ', '타시도 확진자 접촉\r\n(수원 베이비시터 관련)',
#        '강남 이동통신 종사자', '강남구 역삼동 모임 ', '타시도 확진자 접촉\r\n(의정부아파트관련)',
#        '강남구 소재 사무실 ', '관악구 왕성교회', '중랑구 일가족', '관악구 중국동포 일가족', '대전 꿈꾸는 교회',
#        '리치웨이', '현대카드\r\n관악구 왕성교회', '예스병원', '대전 다단계 관련', '리치웨이\r\n[명성하우징]',
#        '도봉구 요양시설 관련', '리치웨이\r\n[SJ투자회사]', '리치웨이\r\n[이민자 쉼터]',
#        '서울시청역 시설개선공사 안전요원관련', '대자연 코리아', '의왕 롯데 물류센터 관련', '금천구 도정기회사 관련',
#        '양천구운동시설', '강남구 오렌지라이프 관련', '수도권 개척교회모임', '국방안보지원사령부 ',
#        '연아나 뉴스클래스', '예수제자교회\r\n한국대학생\r\n선교회(CCC)\r\n관련', '부천 대웅제약',
#        '리치웨이\r\n[예수비젼성결교회]', 'KB생명', 'coupang', '이태원 클럽 관련', '용인형제',
#        '삼성화재', '서초구 가족관련', '안양 목회자\r\n관련', '(인천계양구일가족관련) 연세나로학원',
#        '강남구 동인교회 관련\r\n(구리시 일가족)', '원어성경연구회', '관악구 투석환자 관련', '은평구가족 관련',
#        '영랜브란트미술학원', '삼성서울병원', '위에화엔터테인먼트', '타시도 확진자 접촉\r\n[의정부성모]',
#        '만민중앙교회', '의정부성모', 'Liquid Soul', 'ㅋㅋ트랜드', '이에스에스콤글로벌', '서울아산병원',
#        'Ace 손해보험', '플링크(IT기업)', '성남 은혜의강 교회', '삼성물산', '동대문관련(교회pc방)',
#        'EZHLD', '동대문관련(요양보호사)', '신 천 지', '세브란스', '성동구 아파트 관리사무소',
#        '은평성모병원', '명성교회', '종로구 집단발병'], dtype=object)

# %% [markdown]
# 상위 30개 접촉력 확진수를 시각화합니다.

# %%
# 접촉력 상위 30개만 시각화 시각화
contact_count_top = df["접촉력"].value_counts().sort_values().tail(30)
contact_count_top.plot.barh(figsize=(10,12))

# %% [markdown]
# 기타 확진자 접촉이 가장 많은 것으로 보아 n차 감염이 가장 큰 확산세의 원인이 되었음을 알 수 있고, 아직 감염경로를 모르는 확진자도 많은 것으로 보아 역학 조사에 어려움이 있음을 알 수 있습니다. 이 두 가지 문제에 대한 해결책이 필요한 시점이라 생각이 듭니다.

# %% [markdown]
# 위 결과 중, 상위 15개 접촉력 데이터만 추출해서 데이터를 가져옵니다.

# %%
top_contact = contact_count_top.tail(15)
top_contact
# Out:
# 서초구 사우나Ⅱ 관련             86
# Ace 손해보험                98
# 마포구 홍대새교회 관련           109
# 8.15서울도심집회             126
# 이태원 클럽 관련              139
# 강서구 댄스교습관련 시설          224
# 구로구 소재 요양병원/요양원 관련     226
# 종로구 소재 파고다타운 관련        227
# 강서구 교회 관련              246
# 성북구 사랑제일교회 관련          641
# 해외유입                   805
# 타시도 확진자 접촉            1054
# 동부구치소 관련              1175
# 감염경로 조사중              5655
# 기타 확진자 접촉             7595
# Name: 접촉력, dtype: int64

# %%
top_group = df[df["접촉력"].isin(top_contact.index)]
top_group
# Out:
#           연번     환자        확진일  거주지 여행력        접촉력 퇴원현황     년  월  주
# 0      24395  78560 2021-02-01  마포구   -   감염경로 조사중  NaN  2021  2  5
# 1      24394  78588 2021-02-01  타시도   -   감염경로 조사중  NaN  2021  2  5
# 2      24393  78822 2021-02-01  강남구   -  기타 확진자 접촉  NaN  2021  2  5
# 4      24391  78825 2021-02-01  관악구   -   감염경로 조사중  NaN  2021  2  5
# 5      24390  78824 2021-02-01  관악구   -  기타 확진자 접촉  NaN  2021  2  5
# ...      ...    ...        ...  ...  ..        ...  ...   ... .. ..
# 24387      8     13 2020-02-02  타시도  중국       해외유입   퇴원  2020  2  5
# 24390      5      9 2020-01-31  성북구   -  기타 확진자 접촉   퇴원  2020  1  5
# 24391      4      7 2020-01-30  마포구  중국       해외유입   퇴원  2020  1  5
# 24393      2      5 2020-01-30  중랑구  중국       해외유입   퇴원  2020  1  5
# 24394      1      2 2020-01-24  강서구  중국       해외유입   퇴원  2020  1  4
#
# [18406 rows x 10 columns]

# %% [markdown]
# **1) 2020년 월별 접촉력 확진자 수를 시각화합니다.**

# %%
top_group_2020 = top_group[top_group["년"]==2020].groupby(["접촉력", "월"])["연번"].count().unstack().fillna(0).astype(int)
top_group_2020.style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# #T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col10,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col11,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col10,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col11,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow3_col10,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow5_col10,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow6_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow7_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow8_col11,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow9_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow9_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow9_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow9_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow9_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow9_col5,#T_d8a4d2c9_65eb_11eb_a5 ...
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col7{
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow0_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow10_col8{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col10{
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow1_col3,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow4_col11,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow13_col3{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col3{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col2{
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col4{
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col5,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col6,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col9,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow6_col1,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow6_col8,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow6_col10,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow6_col11,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow10_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow11_col4,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow14_col0,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow14_col2,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow14_col3{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col7,#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow6_col7{
#             background-color:  #2e7ebc;
#             color:  #000000;
#         }#T_d8a4d2c9_65eb_11eb_a50b_54e1ade7a93crow2_col8{
#             background

# %% [markdown]
# * 2020년 2월부터 기타 확진자 접촉, 타시도 확진자 접촉으로 인한 확진자가 발생하면서 n차 감염 위험성이 발생했습니다.
# * 2020년 3월부터 해외유입과 Ace 손해보험 확진자가 급증하면서, 감염경로를 파악하지 못한 환자도 발생합니다. 또한, n차 감염이 여전히 발생합니다.
# * 2020년 4월에는 지역사회 감염이 다소 안정기에 접어들었으나 여전히 해외유입 확진자는 많았습니다.
# * 2020년 5월에는 이태원 클럽 확진자가 폭증했습니다.
# * 2020년 6월, 7월에 다시 n차 감염이 확산되었고, 이는 4월과 5월에 해외유입 확진자와 이태원 클럽 관련 확진자의 영향으로 판단됩니다.
# * 2020년 8월에는 8.15서울도심집회 확진자와 성북구 사랑제일교회 확진자가 폭증합니다. 이에 따라 n차 감염과 감염경로가 불투명한 확진자 역시도 폭등합니다.
# * 2020년 9월, 10월까지 n차 감염이 심하게 확산되는 것을 볼 수 있습니다.
# * 2020년 11월에는 강서구 댄스교습관련 확진자, 마포구 홍대새교회 확진자, 서초구 사우나 관련 확진자가 발생하면서 아직 n차 감염이 여전한 상황이었는데, 확산이 더 심해지게 되었습니다.
# * 2020년 12월에는 동부구치소, 종로구 소재 파고다타운, 구로구 소재 요양병원, 강서구 교회에서 확진자가 발생하면서 n차 감염 역시도 폭증하는 것을 볼 수 있습니다.

# %% [markdown]
# **2) 2021년 월별 접촉력 확진자 수를 시각화합니다.**

# %%
top_group_2021 = top_group[top_group["년"]==2021].groupby(["접촉력", "월"])["연번"].count().unstack().fillna(0).astype(int)
top_group_2021.style.background_gradient(cmap="Greens")
# Out:
# <style  type="text/css" >
# #T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow0_col0{
#             background-color:  #319a50;
#             color:  #000000;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow0_col1{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow1_col0,#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow1_col1,#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow2_col1,#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow4_col1{
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow2_col0{
#             background-color:  #f5fbf3;
#             color:  #000000;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow3_col0,#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow3_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow4_col0{
#             background-color:  #e5f5e1;
#             color:  #000000;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow5_col0{
#             background-color:  #e8f6e3;
#             color:  #000000;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow5_col1{
#             background-color:  #d1edcb;
#             color:  #000000;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow6_col0{
#             background-color:  #ecf8e8;
#             color:  #000000;
#         }#T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow6_col1{
#             background-color:  #d7efd1;
#             color:  #000000;
#         }</style><table id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93c" ><thead>    <tr>        <th class="index_name level0" >월</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>    </tr>    <tr>        <th class="index_name level0" >접촉력</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93clevel0_row0" class="row_heading level0 row0" >감염경로 조사중</th>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow0_col0" class="data row0 col0" >1360</td>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow0_col1" class="data row0 col1" >34</td>
#             </tr>
#             <tr>
#                         <th id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93clevel0_row1" class="row_heading level0 row1" >강서구 교회 관련</th>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow1_col1" class="data row1 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93clevel0_row2" class="row_heading level0 row2" >구로구 소재 요양병원/요양원 관련</th>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow2_col0" class="data row2 col0" >27</td>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow2_col1" class="data row2 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93clevel0_row3" class="row_heading level0 row3" >기타 확진자 접촉</th>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow3_col0" class="data row3 col0" >1977</td>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow3_col1" class="data row3 col1" >38</td>
#             </tr>
#             <tr>
#                         <th id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93clevel0_row4" class="row_heading level0 row4" >동부구치소 관련</th>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow4_col0" class="data row4 col0" >242</td>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow4_col1" class="data row4 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93clevel0_row5" class="row_heading level0 row5" >타시도 확진자 접촉</th>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow5_col0" class="data row5 col0" >210</td>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow5_col1" class="data row5 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93clevel0_row6" class="row_heading level0 row6" >해외유입</th>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow6_col0" class="data row6 col0" >149</td>
#                         <td id="T_b4159900_65ed_11eb_a6c2_54e1ade7a93crow6_col1" class="data row6 col1" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# * 2021년 1월에는 2020년 12월의 n차 감염 여파가 여전히 성행하고 있는 것을 알 수 있고, 동부구치소 관련 확진자와 요양병원 확진자도 발생하고 있음을 알 수 있습니다.

# %% [markdown]
# ## 감염경로 불명
# 감염경로가 불투명한 확진자 정보를 분석한 결과, 2020년 8월에 감염경로 불투명 환자가 증가 후에 감소세를 보이다가 다시 11월에 증가하고, 12월에는 폭증하는 것을 확인할 수 있습니다. 이를 통해 확진자수가 많을수록 감염경로가 불명한 환자 역시도 증가하는 것을 알 수 있습니다. <font color='red'>-> 이에 대응할 수 있는 역학 조사관 인력이 더 많이 필요하다는 것을 알 수 있습니다.</font>

# %%
df_unknown = df[df["접촉력"]=='감염경로 조사중']
df_unknown.head()
# Out:
#       연번     환자        확진일   거주지 여행력       접촉력 퇴원현황     년  월  주
# 0  24395  78560 2021-02-01   마포구   -  감염경로 조사중  NaN  2021  2  5
# 1  24394  78588 2021-02-01   타시도   -  감염경로 조사중  NaN  2021  2  5
# 4  24391  78825 2021-02-01   관악구   -  감염경로 조사중  NaN  2021  2  5
# 6  24389  78798 2021-02-01  영등포구   -  감염경로 조사중  NaN  2021  2  5
# 7  24388  78802 2021-02-01   노원구   -  감염경로 조사중  NaN  2021  2  5

# %%
unknown_weekly_case = df_unknown.groupby(["년", "월"])["연번"].count()
unknown_weekly_case.plot.bar(figsize=(15,4), rot=45)

# %% [markdown]
# 전체 확진자 중에 감염 경로가 불분명한 확진자를 비교하기 위해 전체 확진수 데이터프레임과 감염 경로가 불분명한 확진수 데이터프레임을 각각 생성한 후, 병합(merge)을 수행합니다. 상세히 확인하기 위해 ("년", "주") 별로 데이터프레임을 생성합니다.

# %%
# 1) 전체 확진수
all_weekly_case = df[["년", "주"]].value_counts().to_frame()
all_weekly_case.columns = ["전체확진수"]
all_weekly_case
# Out:
#          전체확진수
# 년    주
# 2020 52   2693
#      51   2654
#      50   1975
#      53   1633
#      49   1627
# 2021 1    1456
# 2020 48   1182
# 2021 2    1002
# 2020 35    921
#      34    912
# 2021 3     844
# 2020 47    820
# 2021 4     807
#      53    769
# 2020 36    459
#      46    432
#      33    394
#      37    341
#      45    291
#      38    280
#      44    250
#      39    237
#      41    170
#      40    164
#      42    139
#      23    134
#      14    129
# 2021 5     128
# 2020 43    127
#      24    125
#      11    124
#      25    105
#      13    105
#      30     97
#      22     88
#      26     78
#      32     76
#      12     76
#      27     67
#      9      61
#      28     57
#      19     52
#      29     48
#      20     47
#      15     47
#      21     39
#      10     38
#      31     38
#      8      17
#      16     15
#      18      8
#      5       7
#      6       4
#      17      3
#      7       2
#      4       1

# %%
# 2) 경로가 불분명한 확진수
unknown_weekly_case = df_unknown[["년", "주"]].value_counts().to_frame()
unknown_weekly_case.columns = ["불명확진수"]
unknown_weekly_case
# Out:
#          불명확진수
# 년    주
# 2020 52    843
#      51    806
#      50    507
# 2021 1     403
# 2020 53    361
#      49    278
# 2021 2     277
#      3     233
#      53    231
# 2020 35    222
# 2021 4     216
# 2020 48    216
#      34    163
#      47    131
#      36     94
#      37     77
#      38     72
#      46     51
#      39     42
#      45     41
#      44     36
#      41     35
# 2021 5      34
# 2020 40     30
#      33     23
#      42     22
#      24     19
#      12     18
#      43     16
#      23     16
#      25     15
#      32     14
#      14     14
#      30     13
#      27     13
#      28     11
#      26     11
#      29      9
#      31      9
#      13      8
#      11      8
#      22      4
#      9       4
#      16      3
#      10      3
#      15      2
#      20      1

# %%
# 1)과 2)를 한 개 데이터프레임으로 merge!
# => how='inner': 시각화할때, all_weekly_case와 unknown_weekly_case에 모두 존재하는 데이터만 고려하기 위함!
unknown_case = all_weekly_case.merge(unknown_weekly_case, left_index=True, right_index=True)
unknown_case = unknown_case.sort_index()
unknown_case
# Out:
#          전체확진수  불명확진수
# 년    주
# 2020 9      61      4
#      10     38      3
#      11    124      8
#      12     76     18
#      13    105      8
#      14    129     14
#      15     47      2
#      16     15      3
#      20     47      1
#      22     88      4
#      23    134     16
#      24    125     19
#      25    105     15
#      26     78     11
#      27     67     13
#      28     57     11
#      29     48      9
#      30     97     13
#      31     38      9
#      32     76     14
#      33    394     23
#      34    912    163
#      35    921    222
#      36    459     94
#      37    341     77
#      38    280     72
#      39    237     42
#      40    164     30
#      41    170     35
#      42    139     22
#      43    127     16
#      44    250     36
#      45    291     41
#      46    432     51
#      47    820    131
#      48   1182    216
#      49   1627    278
#      50   1975    507
#      51   2654    806
#      52   2693    843
#      53   1633    361
# 2021 1    1456    403
#      2    1002    277
#      3     844    233
#      4     807    216
#      5     128     34
#      53    769    231

# %%
unknown_case.plot(figsize=(15,4))
plt.grid(True)

# %% [markdown]
# 대체적으로 전체 확진자수가 증가할 때, 감염 경로가 불분명한 확진자도 증가하는 것을 알 수 있습니다. 이에 대한 원인으로 증가하는 환자를 한 명씩 역학 조사해야 하는 인력 부족이 원인이 될 수 있습니다. 또한, 올바른 이동 동선을 제공하지 않는 경우에도 이와 같은 현상이 발생할 수 있습니다.

# %% [markdown]
# 마지막으로, 전체 확진수 중에 불명 확진수 비율을 시각화해봤습니다.

# %%
# 전체확진수 중에 불명확인수 비율 시각화
unknown_case["확인중비율"] = (unknown_case["불명확진수"]/unknown_case["전체확진수"])*100
unknown_case["확인중비율"].plot.bar(figsize=(15,4))
plt.grid(True)

# %% [markdown]
# 2020년 50주차, 즉 12월이 가장 감염 경로가 불확실한 환자 비율이 크다고 볼 수 있습니다.

# %% [markdown]
# # 퇴원, 사망여부
# 데이터 수집 시점(2021-02-02)에서의 퇴원 및 사망 비율을 분석합니다.

# %%
df["퇴원현황"].unique()
# Out:
# array([nan, '사망', '퇴원'], dtype=object)

# %%
df["퇴원"] = df["퇴원현황"].str.contains("퇴원", na=False) # na=False: 퇴원현황이 Nan인 경우에 False로 반환하도록 설정
df["사망"] = df["퇴원현황"].str.contains("사망", na=False)

# %%
df["퇴원"].value_counts(normalize=True)
# Out:
# True     0.838328
# False    0.161672
# Name: 퇴원, dtype: float64

# %%
df["사망"].value_counts(normalize=True)
# Out:
# False    0.986637
# True     0.013363
# Name: 사망, dtype: float64

# %% [markdown]
# 데이터 수집 시점(2021-02-02)의 퇴원 확률은 약 83%, 사망 확률은 약 0.01%임을 알 수 있습니다. 대체로 퇴원이 순조로움을 알 수 있으며, 사망 확률도 매우 낮은 것을 알 수 있습니다.

# %% [markdown]
# 이제 데이터 수집 시점 기준으로 서울에 거주하는 환자 중에 가장 오래 입원한 확진자를 알아 보았습니다.

# %%
df_seoul = df[df["거주지"].isin(gu_count.index)]
df_seoul
# Out:
#           연번     환자        확진일  거주지 여행력         접촉력 퇴원현황     년  월  주     퇴원  \
# 0      24395  78560 2021-02-01  마포구   -    감염경로 조사중  NaN  2021  2  5  False
# 2      24393  78822 2021-02-01  강남구   -   기타 확진자 접촉  NaN  2021  2  5  False
# 3      24392  78826 2021-02-01  관악구   -  광진구 음식점 관련  NaN  2021  2  5  False
# 4      24391  78825 2021-02-01  관악구   -    감염경로 조사중  NaN  2021  2  5  False
# 5      24390  78824 2021-02-01  관악구   -   기타 확진자 접촉  NaN  2021  2  5  False
# ...      ...    ...        ...  ...  ..         ...  ...   ... .. ..    ...
# 24390      5      9 2020-01-31  성북구   -   기타 확진자 접촉   퇴원  2020  1  5   True
# 24391      4      7 2020-01-30  마포구  중국        해외유입   퇴원  2020  1  5   True
# 24392      3      6 2020-01-30  종로구   -    종로구 집단발병   퇴원  2020  1  5   True
# 24393      2      5 2020-01-30  중랑구  중국        해외유입   퇴원  2020  1  5   True
# 24394      1      2 2020-01-24  강서구  중국        해외유입   퇴원  2020  1  4   True
#
#           사망
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
# ...      ...
# 24390  False
# 24391  False
# 24392  False
# 24393  False
# 24394  False
#
# [21425 rows x 12 columns]

# %%
# 퇴원 == False & 사망 == False 
df_seoul[(df_seoul["퇴원"]==False) & (df_seoul["사망"]==False)].tail()
# Out:
#          연번     환자        확진일  거주지 여행력                         접촉력 퇴원현황     년  \
# 17892  6503  27936 2020-11-11  용산구   -                    감염경로 조사중  NaN  2020
# 18007  6388  27596 2020-11-09  강서구   -                   기타 확진자 접촉  NaN  2020
# 18500  5895  26209 2020-10-28  중랑구   -  기타 확진자 접촉\r\n[경기도 SRC재활병원]  NaN  2020
# 18971  5424  24316 2020-10-06  중랑구   -                    감염경로 조사중  NaN  2020
# 19641  4754  22411 2020-09-15  마포구   -             강남구 소재 대우디오빌플러스  NaN  2020
#
#         월   주     퇴원     사망
# 17892  11  46  False  False
# 18007  11  46  False  False
# 18500  10  44  False  False
# 18971  10  41  False  False
# 19641   9  38  False  False

# %% [markdown]
# 강남구 소재 대우디오빌플러스에서 감염된 서울 마포구 거주자 #4754번 환자가 데이터 수집 시점(2021-02-01) 기준으로 4개월 이상 가장 오래 입원한 상태

# %% [markdown]
# # 여행력
# 전체 확진수와 여행력이 있는 확진수의 관계를 분석합니다.

# %%
df["여행력"].unique()
# Out:
# array(['-', '오스트리아', '스페인', '러시아', '미국', 'UAE', '이라크', '덴마크', '우즈베키스탄',
#        '콩고민주공화국', '일본', '프랑스', '독일', '아이티공화국', '캐나다', '터키', '탄자니아', '영국',
#        '인도네시아', '파키스탄', '아랍에미리트', '이집트', '스리랑카', '폴란드', '에티오피아', '에콰도르',
#        '캄보디아', '인도', '싱가포르', '르완다', '나이지리아', '미얀마', '벨기에', '콩고', '모로코',
#        '네팔', '우크라이나', '헝가리', '스웨덴', '브라질', '방글라데시', '멕시코', '시리아', '리투아니아',
#        '두바이', '중국', '호주', '필리핀', '몰타', '남아공', '알제리', '가나', '알바니아', '핀란드',
#        '네덜란드', '아르헨티나', '가봉', '사우디아라비아', '이탈리아', '쿠웨이트', '크로아티아', '28238',
#        '케냐', '수단', '루마니아', '튀니지', '에디오피아', '키르기스스탄', '이란', '체코', '요르단',
#        '우간다', '카타르', '키르기즈스탄', '파라과이', '멕시코, 미국', '카자흐스탄', '21263', '베트남',
#        '홍콩', '모로코, 터키', '미국, 멕시코', '페루', '아일랜드', '아프리카',
#        '프랑스, 스페인, 이탈리아, 독일, 네덜란드', '오세아니아', '호주, 인도네시아', '포르투갈', '유럽',
#        '미국, 캐나다, 멕시코', '미국, 브라질', '태국', '아시아', '아르헨티나, 볼리비아, 브라질',
#        '말레이시아, 인도네시아', '브라질,아르헨티아,칠레,볼리비아', '프랑스, 독일', '스페인, 카타르',
#        '이탈리아, 프랑스', '체코, 헝가리, 오스트리아, 이탈리아, 프랑스', '오스트리아, 모로코, 프랑스',
#        '독일, 프랑스', '싱가폴'], dtype=object)

# %% [markdown]
# 데이터 전처리를 위해 새로운 칼럼을 생성하여 여행력 데이터를 저장합니다. 여행력이 없는 확진자의 경우, '-' 기호를 Nan으로 변경합니다. **(데이터를 전처리 할 때는 새로운 칼럼을 생성해서 전처리한 결과를 저장하는 것이 좋습니다.)**

# %%
df["해외"] = df["여행력"]
df["해외"] = df["해외"].replace('-', np.nan) 
df["해외"].nunique() # 결측치를 제외한(default dropna=True) unique한 데이터 개수
# Out:
# 103

# %%
df["해외"].value_counts().head(10)
# Out:
# 미국        278
# 영국         58
# 필리핀        29
# 러시아        27
# 일본         23
# 프랑스        22
# 인도네시아      21
# 우즈베키스탄     19
# 인도         17
# 스페인        14
# Name: 해외, dtype: int64

# %% [markdown]
# 미국 여행력이 있는 확진자가 가장 큰 차이로 많으며, 영국, 필리핀, 러시아 여행력을 가진 확진자가 많습니다.

# %% [markdown]
# ## 여행력이 있는 데이터만 가져와서 서브셋 만들기

# %%
df_oversea = df[df["해외"].notnull()].copy()
df_oversea.head()
# Out:
#        연번     환자        확진일  거주지    여행력   접촉력 퇴원현황     년  월  주     퇴원     사망  \
# 15  24380  78759 2021-02-01  용산구  오스트리아  해외유입  NaN  2021  2  5  False  False
# 51  24344  78698 2021-02-01  성북구    스페인  해외유입  NaN  2021  2  5  False  False
# 59  24336  78665 2021-02-01  성북구    러시아  해외유입  NaN  2021  2  5  False  False
# 60  24335  78664 2021-02-01  성북구    러시아  해외유입  NaN  2021  2  5  False  False
# 70  24325  78683 2021-02-01  동작구     미국  해외유입  NaN  2021  2  5  False  False
#
#        해외
# 15  오스트리아
# 51    스페인
# 59    러시아
# 60    러시아
# 70     미국

# %%
df_oversea["해외"].unique()
# Out:
# array(['오스트리아', '스페인', '러시아', '미국', 'UAE', '이라크', '덴마크', '우즈베키스탄',
#        '콩고민주공화국', '일본', '프랑스', '독일', '아이티공화국', '캐나다', '터키', '탄자니아', '영국',
#        '인도네시아', '파키스탄', '아랍에미리트', '이집트', '스리랑카', '폴란드', '에티오피아', '에콰도르',
#        '캄보디아', '인도', '싱가포르', '르완다', '나이지리아', '미얀마', '벨기에', '콩고', '모로코',
#        '네팔', '우크라이나', '헝가리', '스웨덴', '브라질', '방글라데시', '멕시코', '시리아', '리투아니아',
#        '두바이', '중국', '호주', '필리핀', '몰타', '남아공', '알제리', '가나', '알바니아', '핀란드',
#        '네덜란드', '아르헨티나', '가봉', '사우디아라비아', '이탈리아', '쿠웨이트', '크로아티아', '28238',
#        '케냐', '수단', '루마니아', '튀니지', '에디오피아', '키르기스스탄', '이란', '체코', '요르단',
#        '우간다', '카타르', '키르기즈스탄', '파라과이', '멕시코, 미국', '카자흐스탄', '21263', '베트남',
#        '홍콩', '모로코, 터키', '미국, 멕시코', '페루', '아일랜드', '아프리카',
#        '프랑스, 스페인, 이탈리아, 독일, 네덜란드', '오세아니아', '호주, 인도네시아', '포르투갈', '유럽',
#        '미국, 캐나다, 멕시코', '미국, 브라질', '태국', '아시아', '아르헨티나, 볼리비아, 브라질',
#        '말레이시아, 인도네시아', '브라질,아르헨티아,칠레,볼리비아', '프랑스, 독일', '스페인, 카타르',
#        '이탈리아, 프랑스', '체코, 헝가리, 오스트리아, 이탈리아, 프랑스', '오스트리아, 모로코, 프랑스',
#        '독일, 프랑스', '싱가폴'], dtype=object)

# %% [markdown]
# 해외 칼럼에 '28238', '21263'이라는 잘못된 데이터가 들어가 있어서 확인한 결과, 환자 칼럼 데이터임을 확인할 수 있었습니다. 해당 환자의 경우, 여행력을 유추하기 어렵다고 판단하여 제거했습니다.

# %%
df_oversea[df_oversea["해외"]=='28238']
# Out:
#          연번     환자        확진일   거주지    여행력                접촉력 퇴원현황     년   월  \
# 17794  6601  28238 2020-11-13  동대문구  28238  동대문구 에이스희망케어센터 관련   퇴원  2020  11
#
#         주    퇴원     사망     해외
# 17794  46  True  False  28238

# %%
df_oversea[df_oversea["해외"]=='21263']
# Out:
#          연번     환자        확진일  거주지    여행력        접촉력 퇴원현황     년  월   주    퇴원  \
# 20829  3566  21263 2020-08-28  노원구  21263  기타 확진자 접촉   퇴원  2020  8  35  True
#
#           사망     해외
# 20829  False  21263

# %%
df_oversea.drop(df_oversea[df_oversea["해외"]=='28238'].index, inplace=True)
df_oversea.drop(df_oversea[df_oversea["해외"]=='21263'].index, inplace=True)
df_oversea["해외"].unique()
# Out:
# array(['오스트리아', '스페인', '러시아', '미국', 'UAE', '이라크', '덴마크', '우즈베키스탄',
#        '콩고민주공화국', '일본', '프랑스', '독일', '아이티공화국', '캐나다', '터키', '탄자니아', '영국',
#        '인도네시아', '파키스탄', '아랍에미리트', '이집트', '스리랑카', '폴란드', '에티오피아', '에콰도르',
#        '캄보디아', '인도', '싱가포르', '르완다', '나이지리아', '미얀마', '벨기에', '콩고', '모로코',
#        '네팔', '우크라이나', '헝가리', '스웨덴', '브라질', '방글라데시', '멕시코', '시리아', '리투아니아',
#        '두바이', '중국', '호주', '필리핀', '몰타', '남아공', '알제리', '가나', '알바니아', '핀란드',
#        '네덜란드', '아르헨티나', '가봉', '사우디아라비아', '이탈리아', '쿠웨이트', '크로아티아', '케냐',
#        '수단', '루마니아', '튀니지', '에디오피아', '키르기스스탄', '이란', '체코', '요르단', '우간다',
#        '카타르', '키르기즈스탄', '파라과이', '멕시코, 미국', '카자흐스탄', '베트남', '홍콩',
#        '모로코, 터키', '미국, 멕시코', '페루', '아일랜드', '아프리카',
#        '프랑스, 스페인, 이탈리아, 독일, 네덜란드', '오세아니아', '호주, 인도네시아', '포르투갈', '유럽',
#        '미국, 캐나다, 멕시코', '미국, 브라질', '태국', '아시아', '아르헨티나, 볼리비아, 브라질',
#        '말레이시아, 인도네시아', '브라질,아르헨티아,칠레,볼리비아', '프랑스, 독일', '스페인, 카타르',
#        '이탈리아, 프랑스', '체코, 헝가리, 오스트리아, 이탈리아, 프랑스', '오스트리아, 모로코, 프랑스',
#        '독일, 프랑스', '싱가폴'], dtype=object)

# %% [markdown]
# ## 텍스트 데이터 다루기
# 일부 해외 칼럼 데이터를 '유럽', '남미', '중국', 'UAE', '필리핀'으로 통일합니다.
#
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#testing-for-strings-that-match-or-contain-a-pattern

# %% [markdown]
# 유럽에 속하는 나라를 '|'로 구분합니다. 추후 .str.contains()를 통해 국가명을 '유럽'으로 통일할 때, 사용하기 위함입니다.

# %%
europe = "체코,헝가리,오스트리아,이탈리아,프랑스,모로코,독일,스페인,영국,폴란드,터키,아일랜드"
europe = europe.replace(",", "|")
europe
# Out:
# '체코|헝가리|오스트리아|이탈리아|프랑스|모로코|독일|스페인|영국|폴란드|터키|아일랜드'

# %%
df_oversea[df_oversea["해외"].str.contains(europe)]
# Out:
#           연번     환자        확진일   거주지      여행력   접촉력 퇴원현황     년  월   주     퇴원  \
# 15     24380  78759 2021-02-01   용산구    오스트리아  해외유입  NaN  2021  2   5  False
# 51     24344  78698 2021-02-01   성북구      스페인  해외유입  NaN  2021  2   5  False
# 670    23725  76622 2021-01-27   용산구      프랑스  해외유입  NaN  2021  1   4  False
# 738    23657  76042 2021-01-26   송파구       독일  해외유입  NaN  2021  1   4  False
# 801    23594  76039 2021-01-26   용산구       독일  해외유입  NaN  2021  1   4  False
# ...      ...    ...        ...   ...      ...   ...  ...   ... ..  ..    ...
# 24179    216   8063 2020-03-11   성북구  독일, 프랑스  해외유입   퇴원  2020  3  11   True
# 24280    115   6959 2020-03-07   은평구      프랑스  해외유입   퇴원  2020  3  10   True
# 24293    102   5695 2020-03-04  동대문구     이탈리아  해외유입   퇴원  2020  3  10   True
# 24310     85   3681 2020-02-29   강남구     이탈리아  해외유입   퇴원  2020  2   9   True
# 24327     68   3009 2020-02-27   광진구     이탈리아  해외유입   퇴원  2020  2   9   True
#
#           사망       해외
# 15     False    오스트리아
# 51     False      스페인
# 670    False      프랑스
# 738    False       독일
# 801    False       독일
# ...      ...      ...
# 24179  False  독일, 프랑스
# 24280  False      프랑스
# 24293  False     이탈리아
# 24310  False     이탈리아
# 24327  False     이탈리아
#
# [159 rows x 13 columns]

# %% [markdown]
# 남미에 속하는 나라를 '|'로 구분합니다. 추후 .str.contains()를 통해 국가명을 '남미'로 통일할 때, 사용하기 위함입니다.

# %%
# 남미 지역에 해당되는 국가명을 str.contains 로 검색하기 위한 형태로 만듭니다.
south_america = "브라질, 아르헨티아, 칠레, 볼리비아, 멕시코, 페루"
south_america = south_america.replace(", ", "|")
south_america
# Out:
# '브라질|아르헨티아|칠레|볼리비아|멕시코|페루'

# %% [markdown]
# 국가명을 '유럽', '남미', 'UAE', '필리핀', '미국'으로 통일합니다. <font color='red'>다만, '유럽'과 '남미'에 속하는 나라에 여행력을 가진 경우에는 어떻게 처리하는게 맞는지 고민이 필요할 것 같습니다.</font>

# %%
df_oversea.loc[df_oversea["해외"].str.contains(europe), "해외"] = '유럽'
df_oversea.loc[df_oversea["해외"].str.contains(south_america), "해외"] = '남미'
df_oversea.loc[df_oversea["해외"].str.contains('중국|우한'), "해외"] = '중국'
df_oversea.loc[df_oversea["해외"].str.contains('아랍에미리트'), "해외"] = 'UAE'
df_oversea.loc[df_oversea["해외"].str.contains('필리핀'), "해외"] = '필리핀'
df_oversea.loc[df_oversea["해외"].str.contains('미국'), "해외"] = '미국'
df_oversea["해외"]
# Out:
# 15        유럽
# 51        유럽
# 59       러시아
# 60       러시아
# 70        미국
#         ...
# 24386    싱가폴
# 24387     중국
# 24391     중국
# 24393     중국
# 24394     중국
# Name: 해외, Length: 800, dtype: object

# %% [markdown]
# 확진일자와 여행력을 가진 확진수 간의 관계를 분석합니다.

# %%
df_oversea.head()
# Out:
#        연번     환자        확진일  거주지    여행력   접촉력 퇴원현황     년  월  주     퇴원     사망  \
# 15  24380  78759 2021-02-01  용산구  오스트리아  해외유입  NaN  2021  2  5  False  False
# 51  24344  78698 2021-02-01  성북구    스페인  해외유입  NaN  2021  2  5  False  False
# 59  24336  78665 2021-02-01  성북구    러시아  해외유입  NaN  2021  2  5  False  False
# 60  24335  78664 2021-02-01  성북구    러시아  해외유입  NaN  2021  2  5  False  False
# 70  24325  78683 2021-02-01  동작구     미국  해외유입  NaN  2021  2  5  False  False
#
#      해외
# 15   유럽
# 51   유럽
# 59  러시아
# 60  러시아
# 70   미국

# %%
day_oversea = df_oversea.groupby(["확진일", "해외"])["연번"].count()
day_oversea
# Out:
# 확진일         해외
# 2020-01-24  중국     1
# 2020-01-30  중국     2
# 2020-02-02  중국     1
# 2020-02-05  싱가폴    1
# 2020-02-06  중국     2
#                   ..
# 2021-01-31  이라크    1
# 2021-02-01  UAE    1
#             러시아    3
#             미국     1
#             유럽     2
# Name: 연번, Length: 543, dtype: int64

# %% [markdown]
# 확진일자 및 해외(여행력 칼럼 데이터 전처리) 칼럼별 누적 확진자수를 계산합니다. day_oversea가 MultiIndex dataframe이기 때문에 level=[1]로 지정하면, 가장 바깥쪽 최상위 인덱스("확진일")의 하위 인덱스("해외")를 기준으로 삼을 수 있습니다. level=[-1]로 지정해도 동일한 결과를 출력합니다.

# %%
day_oversea = day_oversea.groupby(level=[1]).cumsum()
day_oversea
# Out:
# 확진일         해외
# 2020-01-24  중국       1
# 2020-01-30  중국       3
# 2020-02-02  중국       4
# 2020-02-05  싱가폴      1
# 2020-02-06  중국       6
#                   ...
# 2021-01-31  이라크     12
# 2021-02-01  UAE     12
#             러시아     27
#             미국     278
#             유럽     162
# Name: 연번, Length: 543, dtype: int64

# %%
df_day_oversea = day_oversea.reset_index()
df_day_oversea = df_day_oversea.rename(columns={"연번": '누적확진수'})
df_day_oversea.head()

# %%
# 각 해외(=여행력) 별 누적 확진자수 발생빈도 -> 빈도가 많을수록 많은날동안 확진자 발생! 
oversea_count = df_day_oversea["해외"].value_counts()
oversea_count.sort_values().plot.barh(figsize=(10,12))
plt.grid(True)

# %% [markdown]
# 누적 확진자 발생 빈도는 미국, 유럽, 필리핀 순 -> 우리나라 국민들이 주로 미국, 유럽, 필리핀에서 입국하고 있음을 알 수 있음(여행 등 다양한 목적)

# %%
# 확진 일자 및 해외(=여행력) 칼럼 별 누적 확진자수 피벗 테이블 생성!
df_day_oversea = df_day_oversea.set_index("확진일자")
# "해외"(=여행력) 인덱스를 펼쳐서 피봇테이블 생성 후, 시각화!
# -> 여기서 이전에 df_day_oversea = df_day_oversea.pivot(columns="해외")로 새롭게 정의한뒤 아래셀에서 df_day_oversea.loc[df_day_oversea["해외"] == "미국", "누적확진수"].plot()을 수행하려고 하니까 당연히 접근할 수 없었음
# -> **새로운 변수로 저장할때는 항상 주의를 기울어야함!**
df_day_oversea.pivot(columns="해외").plot(figsize=(24, 4), legend=False)

# %% [markdown]
# 2020년 2월전에 중국에 여행력이 있는 확진자가 최초 발생하여 2020년 3월말부터 급속도로 증가했다.
# 2020년 3월 전후로 유럽(?)에 여행력이 있는 확진자가 발생했으며, 3월 중순이후로 급속도로 증가했다.

# %%
df_day_oversea["해외"].head()

# %%
df_day_oversea.loc[df_day_oversea["해외"] == "미국", "누적확진수"].plot()

# %% [markdown]
# 3월 이후로 미국에 여행력이 있는 누적 확진자 급증, 4월 중순 이후로 누적 확진자 증가세가 완만해짐

# %%
df_oversea.sample()

# %%
# oversea_count_gu: 여행력이 존재하는 데이터(df_oversea)의 거주지역 별 확진자수
# -> 타지역: 서울시를 제외한 지방 시,도
oversea_count_gu = df_oversea["지역"].value_counts()
oversea_count_gu

# %%
oversea_count_gu.sort_values().plot.barh(figsize=(10,12))

# %% [markdown]
# 여행력을 가진 확진자가 가장 많이 거주하는 곳은 강남구, 서초구, 송파구, 타지역 순

# %% [markdown]
# ## 전체 확진수와 해외유입(-> 여행력이 존재하는 경우) 확진수 비교

# %% [markdown]
# * 1) 전체 확진수

# %%
all_count_gu = df["지역"].value_counts()
all_count_gu

# %%
df_all_gu = all_count_gu.to_frame()
df_all_gu.columns = ["전체확진수"]
df_all_gu

# %% [markdown]
# * 2) 해외유입(-> 여행력이 존재하는) 확진수

# %%
df_oversea_gu = pd.DataFrame({"해외유입확진수(=여행력존재확진수)": oversea_count_gu})
df_oversea_gu

# %% [markdown]
# ## merge를 통해 전체 확진수와 해외유입 확진수 비교하기

# %%
df_all_oversea_case = df_all_gu.merge(df_oversea_gu, left_index=True, right_index=True)
df_all_oversea_case

# %%
df_all_oversea_case.sort_values(by="해외유입확진수(=여행력존재확진수)").plot.barh(figsize=(15,8))

# %% [markdown]
# * 강남구에 거주하는 확진자의 약 50%가 해외 여행력이 존재함
# * 관악구는 전체 확진수가 가장 많지만, 해외 여행력이 존재하는 확진자의 영향은 적음

# %%
# 각 지역별 확진자 중, 해외유입(=여행력이 존재하는) 확진자 비율 
df_all_oversea_case["해외유입비율"] = (df_all_oversea_case["해외유입확진수(=여행력존재확진수)"] / df_all_oversea_case["전체확진수"])*100
df_all_oversea_case.sort_values(by="해외유입비율", ascending=False)

# %% [markdown]
# * 실제로 서초구, 강남구는 전체 확진자의 약 50%가 해외유입(=여행력이 존재하는) 확진자.
# * 데이터 수집 시점에서는 금천구가 가장 비율

# %% [markdown]
# ## 해외유입 확진자 중 퇴원 여부

# %%
oversea_finish_count = df_oversea.groupby(["지역", "퇴원"])["연번"].count().unstack()
oversea_finish_count = oversea_finish_count.fillna(0).astype(int)
oversea_finish_count.plot.bar(rot=30, figsize=(15,4))
plt.grid(True)

# %%
# test add
oversea_finish_count.loc[:,True] / (oversea_finish_count.loc[:,False] + oversea_finish_count.loc[:,True])

# %% [markdown]
# 현재 데이터 수집 시점 기준으로 대부분의 해외유입(=여행이력이 있는) 환자들은 대부분 퇴원했다.

# %% [markdown]
# ## 월별 해외 확진자 수

# %%
df_oversea["월"].value_counts().sort_index().plot()

# %%
df_oversea["월"].value_counts().sort_index().plot.bar(rot=0)

# %% [markdown]
# 해외 유입(=여행력이 있는) 확진자는 3월, 4월에 가장 많았다!

# %% [markdown]
# ## 구와 월별 해외 확진자 수
# * groupby, crosstab, pivot_table로 같은 결과가 나오도록 함!

# %%
month_gu = df_oversea.groupby(["월", "지역"])["연번"].count().unstack()
month_gu = month_gu.fillna(0).astype(int)
month_gu.style.background_gradient(cmap="Greens")

# %% [markdown]
# * 대부분의 지역에서 지역에서 3월 확진자 대다수가 해외유입(여행력을 가짐).
# * 그 뒤를 4월이 따른다.

# %% [markdown]
# ### crosstab으로 빈도수 구하기
# pd.crosstab()

# %%
df_oversea.head(1)

# %%
month_gu = pd.crosstab(df_oversea["월"], df_oversea["지역"])
month_gu.style.bar()

# %% [markdown]
# ### pivot_table로 빈도수 구하기
# * "월" 칼럼에 중복되는 데이터가 많으므로, pivot_table() 사용
# * aggfunc 인자 사용

# %%
# 칼럼 개수가 많아서 30개로 제한을 둠!
pd.options.display.max_columns = 30

# %%
month_gu = pd.pivot_table(df_oversea, index="월", columns="지역", values="연번", aggfunc='count', fill_value=0)
month_gu

# %% [markdown]
# ## 해외유입이 많은 지역(구)

# %%
# 해외유입(여행력)이 많은 지역(구)
top_oversea_gu = df_oversea["지역"].value_counts().head().index
top_oversea_gu

# %%
g = month_gu[top_oversea_gu].plot(figsize=(15, 4))
g.legend(loc=1)

# %% [markdown]
# ## 구별 해외유입 국가 분석하기

# %% [markdown]
# ### groupby로 구하기

# %%
df_oversea.sample()

# %%
group_oversea_gu = df_oversea.groupby(["해외", "지역"])["연번"].count().unstack()
group_oversea_gu.fillna(0).astype(int)

# %% [markdown]
# ### pivot table로 구하기

# %%
group_oversea_gu = pd.pivot_table(df_oversea, index="해외", columns="지역", values="연번", aggfunc='count', fill_value=0)
group_oversea_gu.style.background_gradient()

# %% [markdown]
# ### 일부 구만 따로 보기

# %%
# 강남 3구만 따로 분석해보자!
group_oversea_gu.loc[["미국", "유럽", "남미", "중국"], ["강남구", "서초구", "송파구"]]

# %%
# top_oversea_gu에 따른 해외유입(=여행력을 가진) 확진자수 확인!
group_oversea_gu[top_oversea_gu].astype(int)

# %% [markdown]
# ## 최근 데이터를 불러와 실습해 보기
